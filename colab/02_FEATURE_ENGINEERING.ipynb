# %% [markdown]
# # 02 — Feature engineering and labels
# Academic research only. Errors are persisted before re-raising.

# %%
from omega.features import build_features
from omega.labels import label_phenomena
try:
    X=build_features(df); y=label_phenomena(df)
    display(X.tail()); display(y.mean(numeric_only=True))
except Exception as exc:
    print(f'FAILED: {exc}')
    raise
