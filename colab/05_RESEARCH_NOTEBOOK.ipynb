# %% [markdown]
# # 05 — Research sandbox
# Academic research only. Errors are persisted before re-raising.

# %%
# Register hypotheses before experimentation. Do not use the final test period for idea selection.
from omega.features import REGISTRY
{k:v['rationale'] for k,v in REGISTRY.items()}
