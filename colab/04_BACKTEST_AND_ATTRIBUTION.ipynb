# %% [markdown]
# # 04 — Hypothetical response and attribution
# Academic research only. Errors are persisted before re-raising.

# %%
import json
from pathlib import Path
for name in ['attribution.json','hypothetical_backtest.json']:
    p=Path('artifacts/colab_run')/name
    if p.exists(): print(name, json.loads(p.read_text()))
