# %% [markdown]
# # 03 — Calibrated temporal baselines
# Academic research only. Errors are persisted before re-raising.

# %%
from omega.config import load_config
from omega.pipeline import run_pipeline
try:
    cfg=load_config(); metrics=run_pipeline(df,cfg,'artifacts/colab_run')
    display(metrics.groupby(['label','model']).mean(numeric_only=True))
except Exception as exc:
    print(f'FAILED: {exc}')
    raise
